# %%
! pip uninstall numpy -y

# %%
! pip install numpy

# %%
! pip uninstall cython -y

# %%
! pip install cython

# %%
! pip uninstall ripser -y

# %%
! pip install ripser

# %%
import numpy as np

import pandas as pd

import scipy as sp
import scipy.interpolate

import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
import plotly.figure_factory as ff

from itertools import combinations

from collections import OrderedDict


from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LinearRegression

# %%
import os
import sys
sys.path.insert(0,r'/Users/seanippolito/repos/theseankid/computational-topology/distances')
import ellipsoid_distances
import tadasets

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Circle

import sympy as sym
from sympy import lambdify
from sympy import Matrix

x = sym.Symbol('x')
y = sym.Symbol('y')
f = x**2 + y**2 - 1
variables = [x,y]

# %%
seed=5
data=tadasets.dsphere(n=50, d=1)
sigma = 0.2

# %%
ED = ellipsoid_distances.euclidean_distance_matrix(data, normalize = True)
JD = ellipsoid_distances.jacobian_ellipsoid_distances(data, f, variables, sigma=0.2)
SD = ellipsoid_distances.svd_ellipsoid_distances(data, sigma=0.2)

# %%
from ripser import ripser
from persim import plot_diagrams
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets

# %%
dgms_ED = ripser(ED, distance_matrix=True, maxdim=2)['dgms']
plot_diagrams(dgms_ED, show=True)#, lifetime=True)

# %%
dgms_JD = ripser(JD, distance_matrix=True, maxdim=2)['dgms']
plot_diagrams(dgms_JD, show=True)#, lifetime=True)

# %%
dgms_SD = ripser(SD, distance_matrix=True, maxdim=2)['dgms']
plot_diagrams(dgms_SD, show=True)#, lifetime=True)
