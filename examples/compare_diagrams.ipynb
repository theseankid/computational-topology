# %%
import numpy as np

import pandas as pd

import scipy as sp
import scipy.interpolate

import plotly
import plotly.express as px
import plotly.graph_objects as go
import plotly.offline as py
import plotly.figure_factory as ff

from itertools import combinations

from collections import OrderedDict


from sklearn.neighbors import NearestNeighbors
from sklearn.linear_model import LinearRegression

# %%
import os
import sys
sys.path.insert(0,r'/Users/seanippolito/repos/theseankid/computational-topology/distances')
import ellipsoid_distances
import tadasets

# %%
import time
import datetime

# %%
from ripser import ripser
from persim import plot_diagrams
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse, Circle

import sympy as sym
from sympy import lambdify
from sympy import Matrix

x = sym.Symbol('x')
y = sym.Symbol('y')
f = x**2 + y**2 - 1
variables = [x,y]

# %%
seed=5
data=tadasets.dsphere(n=200, d=1)
sigma = 0.2

plt.scatter(x=data[:,0], y=data[:,1])

# %%
print('200 data points')
times = []
times.append({'dists':'initial', 'time':datetime.datetime.now()})
ED = ellipsoid_distances.euclidean_distance_matrix(data, normalize = True)
times.append({'dists':'ED', 'time':datetime.datetime.now()})
print(times[-1]['time'] - times[-2]['time'])

JD = ellipsoid_distances.jacobian_ellipsoid_distances(data, f, variables, sigma=0.1)
times.append({'dists':'JD', 'time':datetime.datetime.now()})
print(times[-1]['time'] - times[-2]['time'])

SD = ellipsoid_distances.svd_ellipsoid_distances(data, sigma=0.1)
times.append({'dists':'SD', 'time':datetime.datetime.now()})
print(times[-1]['time'] - times[-2]['time'])

ND = ellipsoid_distances.neighbors_distances(data)
times.append({'dists':'ND', 'time':datetime.datetime.now()})
print(times[-1]['time'] - times[-2]['time'])
# Out:
# 200 data points
# 0:00:00.104729
# 0:00:00.394502
# 0:00:00.390884
# 0:00:00.016065

# %%
dgms_ED = ripser(ED, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_ED, ax=plt.subplot(221))

dgms_JD = ripser(JD, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_JD, ax=plt.subplot(222))

dgms_SD = ripser(SD, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_SD, ax=plt.subplot(223))

dgms_ND = ripser(ND, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_ND, ax=plt.subplot(224))

# %%
seed=5
data2=tadasets.dsphere(n=100, d=1, noise = 0.1)
sigma = 0.2

plt.scatter(x=data2[:,0], y=data2[:,1])

# %%
print('200 data points')
times = []
times.append({'dists':'initial', 'time':datetime.datetime.now()})
ED = ellipsoid_distances.euclidean_distance_matrix(data2, normalize = True)
times.append({'dists':'ED', 'time':datetime.datetime.now()})
print(times[-1]['time'] - times[-2]['time'])

JD = ellipsoid_distances.jacobian_ellipsoid_distances(data2, f, variables, sigma=0.1)
times.append({'dists':'JD', 'time':datetime.datetime.now()})
print(times[-1]['time'] - times[-2]['time'])

SD = ellipsoid_distances.svd_ellipsoid_distances(data2, sigma=0.1)
times.append({'dists':'SD', 'time':datetime.datetime.now()})
print(times[-1]['time'] - times[-2]['time'])

ND = ellipsoid_distances.neighbors_distances(data2)
times.append({'dists':'ND', 'time':datetime.datetime.now()})
print(times[-1]['time'] - times[-2]['time'])
# Out:
# 200 data points
# 0:00:00.494120
# 0:00:02.492946
# 0:00:02.408408
# 0:00:00.099971

# %%
dgms_ED = ripser(ED, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_ED, ax=plt.subplot(221))

dgms_JD = ripser(JD, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_JD, ax=plt.subplot(222))

dgms_SD = ripser(SD, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_SD, ax=plt.subplot(223))

dgms_ND = ripser(ND, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_ND, ax=plt.subplot(224))

# %%
np.random.rand(8).reshape(4,2)
# Out:
# array([[0.84865398, 0.36878735],
#        [0.95217624, 0.36979844],
#        [0.32744655, 0.80518434],
#        [0.59794859, 0.32051324]])

# %%
data3 = np.random.rand(400).reshape(200,2)
plt.scatter(x=data3[:,0], y=data3[:,1])

# %%
plt.subplots(figsize=(15,5))
ED3 = ellipsoid_distances.euclidean_distance_matrix(data3, normalize = True)

SD3 = ellipsoid_distances.svd_ellipsoid_distances(data3, sigma=0.1)

ND3 = ellipsoid_distances.neighbors_distances(data3)

dgms_ED3 = ripser(ED3, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_ED3, ax=plt.subplot(131))

dgms_SD3 = ripser(SD3, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_SD3, ax=plt.subplot(132))

dgms_ND3 = ripser(ND3, distance_matrix=True, maxdim=1)['dgms']
plot_diagrams(dgms_ND3, ax=plt.subplot(133))

# %%
np.degrees(np.pi/2)
# Out:
# 90.0
